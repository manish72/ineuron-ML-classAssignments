# %% [markdown]
# # Given dataset is a binary classification based on problem statement

# %% [markdown]
# # EDA and FE

# %%
import pandas as pd
import warnings

warnings.filterwarnings('ignore')

# %%
# Since data header is defined X1,X2,.. to make human readibility, I have considered header row second row in excel file

data = pd.read_excel("default of credit card clients.xls", header=1)

# %%
data.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...          0          0          0         0       689         0
# 1  ...       3272       3455       3261         0      1000      1000
# 2  ...      14331      14948      15549      1518      1500      1000
# 3  ...      28314      28959      29547      2000      2019      1200
# 4  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# ...

# %%
data.tail()
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 29995  29996     220000    1          3         1   39      0      0      0
# 29996  29997     150000    1          3         2   43     -1     -1     -1
# 29997  29998      30000    1          2         2   37      4      3      2
# 29998  29999      80000    1          3         1   41      1     -1      0
# 29999  30000      50000    1          2         1   46      0      0      0
#
#        PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 29995      0  ...      88004      31237      15980      8500     20000
# 29996     -1  ...       8979       5190          0      1837      3526
# 29997     -1  ...      20878      20582      19357         0         0
# 29998      0  ...      52774      11855      48944     85900      3409
# 29999      0  ...      36535      32428      15313      2078      1800
#
#        PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# ...

# %%
data.shape
# Out:
# (30000, 25)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          30000 non-null  int64
#  1   LIMIT_BAL                   30000 non-null  int64
#  2   SEX                         30000 non-null  int64
#  3   EDUCATION                   30000 non-null  int64
#  4   MARRIAGE                    30000 non-null  int64
#  5   AGE                         30000 non-null  int64
#  6   PAY_0                       30000 non-null  int64
#  7   PAY_2                       30000 non-null  int64
#  8   PAY_3                       30000 non-null  int64
#  9   PAY_4                       30000 non-null  int64
#  10  PAY_5                       30000 non-null  int64
#  11  PAY_6                       30000 non-null  int64
#  12  BILL_AMT1                   30000 non-null  int64
# ...

# %%
data.describe(include='all').T
# Out:
#                               count           mean            std       min  \
# ID                          30000.0   15000.500000    8660.398374       1.0
# LIMIT_BAL                   30000.0  167484.322667  129747.661567   10000.0
# SEX                         30000.0       1.603733       0.489129       1.0
# EDUCATION                   30000.0       1.853133       0.790349       0.0
# MARRIAGE                    30000.0       1.551867       0.521970       0.0
# AGE                         30000.0      35.485500       9.217904      21.0
# PAY_0                       30000.0      -0.016700       1.123802      -2.0
# PAY_2                       30000.0      -0.133767       1.197186      -2.0
# PAY_3                       30000.0      -0.166200       1.196868      -2.0
# PAY_4                       30000.0      -0.220667       1.169139      -2.0
# PAY_5                       30000.0      -0.266200       1.133187      -2.0
# ...

# %%
## Since ID column is just for indexing, so removing ID column

data = data.drop(columns=['ID'])

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(8,6))
x=0
for i in data.columns:
    sns.histplot(data=data,x=i,kde=True)
    print('\n')
    plt.show()

# %%
## Checking NULL values

data.isnull().sum().sum() # no NULL values are present
# Out:
# 0

# %%
## Checking unique data
print("Count value")
for i in data.columns:
    print(i)
    print(data[i].value_counts())
    print("====================================================================")
# Out:
# Count value
# LIMIT_BAL
# 50000      3365
# 20000      1976
# 30000      1610
# 80000      1567
# 200000     1528
#            ...
# 730000        2
# 1000000       1
# 327680        1
# 760000        1
# 690000        1
# Name: LIMIT_BAL, Length: 81, dtype: int64
# ...
# SEX
# 2    18112
# 1    11888
# Name: SEX, dtype: int64
# ...
# EDUCATION
# 2    14030
# 1    10585
# 3     4917
# 5      280
# 4      123
# 6       51
# 0       14
# Name: EDUCATION, dtype: int64
# ...
# MARRIAGE
# 2    15964
# 1    13659
# 3      323
# 0       54
# Name: MARRIAGE, dtype: int64
# ...
# AGE
# 29    1605
# 27    1477
# 28    1409
# 30    1395
# 26    1256
# 31    1217
# 25    1186
# 34    1162
# 32    1158
# 33    1146
# 24    1127
# 35    1113
# 36    1108
# 37    1041
# 39     954
# 38     944
# 23     931
# 40     870
# 41     824
# 42     794
# 44     700
# 43     670
# 45     617
# 46     570
# 22     560
# 47     501
# 48     466
# 49     452
# 50     411
# 51     340
# 53     325
# 52     304
# 54     247
# ...

# %%
### Removing duplicates

data = data[~data.duplicated()]
data.shape
# Out:
# (29965, 24)

# %%
## finding correlation again

plt.subplots(figsize=(30,30))   
sns.heatmap(data.corr(),annot=True,center = 0)
# Out:
# <AxesSubplot:>

# %%
data.value_counts('default payment next month').plot.pie(y='default payment next month',startangle=90, explode=(0.2,0), title='Percentage of the default payment', legend=False, autopct='%.2f')
# Out:
# <AxesSubplot:title={'center':'Percentage of the default payment'}, ylabel='None'>

# %%
plt.subplots(figsize=(20,5))
plt.subplot(121)
sns.distplot(data.LIMIT_BAL)

plt.subplot(122)
sns.distplot(data.AGE)

plt.show()

# %%
plt.subplots(figsize=(20,10))

plt.subplot(231)
plt.scatter(y=data.PAY_AMT1, x=data.BILL_AMT1, c='r', s=1)

plt.subplot(232)
plt.scatter(y=data.PAY_AMT2, x=data.BILL_AMT2, c='b', s=1)

plt.subplot(233)
plt.scatter(y=data.PAY_AMT3, x=data.BILL_AMT3, c='g', s=1)

plt.subplot(234)
plt.scatter(y=data.PAY_AMT4, x=data.BILL_AMT4, c='c', s=1)
plt.ylabel("Payment in past 6 months", fontsize=25)

plt.subplot(235)
plt.scatter(y=data.PAY_AMT5, x=data.BILL_AMT5, c='y', s=1)
plt.xlabel("Bill Amount in past 6 months", fontsize=25)

plt.subplot(236)
plt.scatter(y=data.PAY_AMT6, x=data.BILL_AMT6, c='m', s=1)

plt.show()

# %%
# Find average limit balance based on each category

data.groupby('SEX')['LIMIT_BAL'].mean().plot.bar(title='Average Limit Balance based on each Sex category',legend=True)
# Out:
# <AxesSubplot:title={'center':'Average Limit Balance based on each Sex category'}, xlabel='SEX'>

# %%
# Find the limit balance for each Martial Status category

martial_category = data.groupby(['MARRIAGE'])['LIMIT_BAL'].sum().sort_values(ascending=False).reset_index()

# %%
plt.figure(figsize = (14,10))
sns.set_context("talk")
sns.set_style("darkgrid")

ax = sns.barplot(x = 'MARRIAGE' , y = 'LIMIT_BAL' , data = martial_category)
ax.set_xlabel('Marriage Category')
ax.set_ylabel('Limit Balance')
ax.set_title("Total Limit Balance for each marriage category", size = 20)
# Out:
# Text(0.5, 1.0, 'Total Limit Balance for each marriage category')

# %%
data[data['default payment next month'] == 1]
# Out:
#        LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0          20000    2          2         1   24      2      2     -1     -1
# 1         120000    2          2         2   26     -1      2      0      0
# 13         70000    1          2         2   30      1      2      2      0
# 16         20000    1          1         2   24      0      0      2      2
# 21        120000    2          2         1   39     -1     -1     -1     -1
# ...          ...  ...        ...       ...  ...    ...    ...    ...    ...
# 29991     210000    1          2         1   34      3      2      2      2
# 29994      80000    1          2         2   34      2      2      2      2
# 29997      30000    1          2         2   37      4      3      2     -1
# 29998      80000    1          3         1   41      1     -1      0      0
# 29999      50000    1          2         1   46      0      0      0      0
#
# ...

# %%
sns.boxplot(data=data, x='MARRIAGE',y='AGE')
# Out:
# <AxesSubplot:xlabel='MARRIAGE', ylabel='AGE'>

# %% [markdown]
# ## Data Transformation

# %%
X = data.drop(labels=['default payment next month'],axis=1)
Y = data[['default payment next month']]

# %% [markdown]
# #### Test size is 20%

# %%
## Train test split

from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test=train_test_split(X,Y,test_size=0.2,random_state=42)
data_columns = list(data.columns)
data_columns.remove('default payment next month')

# %%
from sklearn.impute import SimpleImputer ## HAndling Missing Values
from sklearn.preprocessing import StandardScaler,PowerTransformer # Handling Feature Scaling
from sklearn.preprocessing import OrdinalEncoder # Ordinal Encoding
## pipelines
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

# %%
## Numerical Pipeline
num_pipeline=Pipeline(
    steps=[
    ('imputer',SimpleImputer(strategy='median')),
    ('scaler',StandardScaler())
    ]
)

preprocessor=ColumnTransformer(transformers=[
('num_pipeline',num_pipeline,data_columns)
])

# %%
X_train=preprocessor.fit_transform(X_train)
X_test=preprocessor.transform(X_test)

# %% [markdown]
# ## Model Training

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,classification_report

# %%
model = LogisticRegression()

model.fit(X_train,y_train)

# Model training score
print(f"Model Score : {model.score(X_train,y_train)}")

#Model Prediction
y_pred = model.predict(X_test)

# Accuacy Score
print(f"Accuracy Score : {accuracy_score(y_test,y_pred)}")

#Classification Report
print(f"Classification Report : \n {classification_report(y_test,y_pred)}")
# Out:
# Model Score : 0.8120347076038404
# Accuracy Score : 0.8076849733028223
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.81      0.97      0.89      8136
#            1       0.72      0.23      0.35      2352
#
#     accuracy                           0.81     10488
#    macro avg       0.77      0.60      0.62     10488
# weighted avg       0.79      0.81      0.77     10488

# %% [markdown]
# ## Hyperparameter tuning

# %% [markdown]
# ### Grid Search CV

# %%
import numpy as np
from sklearn.model_selection import GridSearchCV

# Creating the hyperparameter grid
c_space = np.logspace(-5, 8, 15)
param_grid = {'C': c_space}

# Instantiating the GridSearchCV object
model1 = model
logreg_cv = GridSearchCV(model, param_grid, cv = 5)
 
logreg_cv.fit(X_train, y_train)
 
# Print the tuned parameters and score
print("Tuned Logistic Regression Parameters: {}".format(logreg_cv.best_params_))
print("Best score is {}".format(logreg_cv.best_score_))
# Out:
# Tuned Logistic Regression Parameters: {'C': 31.622776601683793}
# Best score is 0.8119831537826888

# %%
# example of grid searching key hyperparametres for logistic regression with l2 regularization
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression


# define models and parameters
model1 = LogisticRegression()
solvers = ['newton-cg', 'lbfgs', 'liblinear','newton-cholesky','saga','sag']
penalty = ['l2']
c_values = [100, 10, 1.0, 0.1, 0.01]

# define grid search
grid = dict(solver=solvers,penalty=penalty,C=c_values)
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
grid_search = GridSearchCV(estimator=model1, param_grid=grid, n_jobs=-1, cv=cv, scoring='accuracy',error_score=0)
grid_result = grid_search.fit(X_train, y_train)

# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Best: 0.811813 using {'C': 1.0, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.811778 (0.005101) with: {'C': 100, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.811778 (0.005101) with: {'C': 100, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.811778 (0.005101) with: {'C': 100, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.811761 (0.005092) with: {'C': 100, 'penalty': 'l2', 'solver': 'newton-cholesky'}
# 0.811761 (0.004973) with: {'C': 100, 'penalty': 'l2', 'solver': 'saga'}
# 0.811778 (0.005063) with: {'C': 100, 'penalty': 'l2', 'solver': 'sag'}
# 0.811778 (0.005101) with: {'C': 10, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.811761 (0.005078) with: {'C': 10, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.811778 (0.005101) with: {'C': 10, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.811761 (0.005092) with: {'C': 10, 'penalty': 'l2', 'solver': 'newton-cholesky'}
# 0.811761 (0.004973) with: {'C': 10, 'penalty': 'l2', 'solver': 'saga'}
# 0.811795 (0.005086) with: {'C': 10, 'penalty': 'l2', 'solver': 'sag'}
# ...

# %%
# example of grid searching key hyperparametres for logistic regression with l1 regularization
from sklearn.model_selection import RepeatedStratifiedKFold 
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression


# define models and parameters
model2 = LogisticRegression()
solvers = ['saga', 'liblinear']
penalty = ['l1']
c_values = [100, 10, 1.0, 0.1, 0.01]

# define grid search
grid = dict(solver=solvers,penalty=penalty,C=c_values)
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
grid_search = GridSearchCV(estimator=model2, param_grid=grid, n_jobs=-1, cv=cv, scoring='accuracy',error_score=0)
grid_result = grid_search.fit(X_train, y_train)

# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Best: 0.811778 using {'C': 100, 'penalty': 'l1', 'solver': 'liblinear'}
# 0.811778 (0.004987) with: {'C': 100, 'penalty': 'l1', 'solver': 'saga'}
# 0.811778 (0.005101) with: {'C': 100, 'penalty': 'l1', 'solver': 'liblinear'}
# 0.811761 (0.004994) with: {'C': 10, 'penalty': 'l1', 'solver': 'saga'}
# 0.811778 (0.005096) with: {'C': 10, 'penalty': 'l1', 'solver': 'liblinear'}
# 0.811778 (0.005042) with: {'C': 1.0, 'penalty': 'l1', 'solver': 'saga'}
# 0.811727 (0.005141) with: {'C': 1.0, 'penalty': 'l1', 'solver': 'liblinear'}
# 0.811504 (0.004819) with: {'C': 0.1, 'penalty': 'l1', 'solver': 'saga'}
# 0.811521 (0.004968) with: {'C': 0.1, 'penalty': 'l1', 'solver': 'liblinear'}
# 0.807585 (0.004961) with: {'C': 0.01, 'penalty': 'l1', 'solver': 'saga'}
# 0.808783 (0.005098) with: {'C': 0.01, 'penalty': 'l1', 'solver': 'liblinear'}

# %%
# example of grid searching key hyperparametres for logistic regression with elasticnet regularization
from sklearn.model_selection import RepeatedStratifiedKFold 
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression


# define models and parameters
model3 = LogisticRegression(l1_ratio = 0.55)
solvers = ['saga']
penalty = ['elasticnet']
c_values = [100, 10, 1.0, 0.1, 0.01]

# define grid search
grid = dict(solver=solvers,penalty=penalty,C=c_values)
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
grid_search = GridSearchCV(estimator=model3, param_grid=grid, n_jobs=-1, cv=cv, scoring='accuracy',error_score=0)
grid_result = grid_search.fit(X_train, y_train)

# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Best: 0.811830 using {'C': 1.0, 'penalty': 'elasticnet', 'solver': 'saga'}
# 0.811761 (0.004973) with: {'C': 100, 'penalty': 'elasticnet', 'solver': 'saga'}
# 0.811761 (0.004973) with: {'C': 10, 'penalty': 'elasticnet', 'solver': 'saga'}
# 0.811830 (0.005024) with: {'C': 1.0, 'penalty': 'elasticnet', 'solver': 'saga'}
# 0.811539 (0.004863) with: {'C': 0.1, 'penalty': 'elasticnet', 'solver': 'saga'}
# 0.808475 (0.004971) with: {'C': 0.01, 'penalty': 'elasticnet', 'solver': 'saga'}

# %% [markdown]
# ## Model training with Power transformer

# %%
## Numerical Pipeline
num_pipeline=Pipeline(
    steps=[
    ('imputer',SimpleImputer(strategy='median')),
    ('scaler',PowerTransformer())
    ]
)

power_preprocessor = ColumnTransformer(transformers=[
('num_pipeline',num_pipeline,data_columns)
])#.set_output(transform="pandas")

# %%
X_train,X_test,y_train,y_test1=train_test_split(X,Y,test_size=0.2,random_state=42)

X_train=power_preprocessor.fit_transform(X_train)
X_test=power_preprocessor.transform(X_test)

# %%
model = LogisticRegression()

model.fit(X_train,y_train)

# Model training score
print(f"Model Score : {model.score(X_train,y_train)}")

#Model Prediction
y_pred1 = model.predict(X_test)

# Accuacy Score
print(f"Accuracy Score : {accuracy_score(y_test1,y_pred1)}")

#Classification Report
print(f"Classification Report : \n {classification_report(y_test1,y_pred1)}")
# Out:
# Model Score : 0.8038198901268162
# Accuracy Score : 0.8020594965675057
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.81      0.97      0.88      8136
#            1       0.70      0.21      0.32      2352
#
#     accuracy                           0.80     10488
#    macro avg       0.75      0.59      0.60     10488
# weighted avg       0.78      0.80      0.76     10488

# %% [markdown]
# ### auc-roc score

# %%
from sklearn.metrics import roc_auc_score
score = roc_auc_score(y_test, y_pred) # from Standard Scaler preprocessor

score
# Out:
# 0.6021975899504344

# %% [markdown]
# ### Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test,y_pred)  # from Standard Scaler preprocessor

# %%
from sklearn.metrics import ConfusionMatrixDisplay

ConfusionMatrixDisplay(cm).plot()
